# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Load preprocessed data
df = pd.read_csv(r"C:\Users\Musae\Documents\GitHub-REPOs\Crop-Classifier-From-Space\preprocessing\processed_crop_dataset.csv")

# %%
df
# Out:
#            B2      B3      B4      B8  classification    crop        date  \
# 0      0.3872  0.3408  0.2778  0.4896               9   cocoa  2020-01-02
# 1      0.3208  0.3270  0.3078  0.4400               9   cocoa  2020-01-02
# 2      0.1394  0.1676  0.1606  0.3248              10  rubber  2020-01-02
# 3      0.1118  0.1176  0.0910  0.3254              10  rubber  2020-01-02
# 4      0.4050  0.3846  0.3472  0.4612              10  rubber  2020-01-02
# ...       ...     ...     ...     ...             ...     ...         ...
# 29483  0.0365  0.0506  0.0427  0.2053              10  rubber  2020-12-30
# 29484  0.0488  0.0672  0.0539  0.3038              10  rubber  2020-12-30
# 29485  0.1146  0.1306  0.1140  0.2784              10  rubber  2020-12-30
# 29486  0.0524  0.0700  0.0561  0.2658              10  rubber  2020-12-30
# 29487  0.0382  0.0598  0.0477  0.2530              10  rubber  2020-12-30
#
#            NDVI     GNDVI       EVI  crop_label
# ...

# %%
# Feature columns
features = ['B2', 'B3', 'B4', 'B8', 'NDVI', 'GNDVI', 'EVI']

# Encode target labels
df['crop'] = df['crop'].astype('category')
df['crop_label'] = df['crop'].cat.codes  # cocoa=0, oil_palm=1, rubber=2 (check df['crop'].cat.categories)

# Train-test split
X = df[features]
y = df['crop_label']
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# Train classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)

# Predict
y_pred = clf.predict(X_test)

# Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Optional: Show label mapping
print("\nLabel Mapping:", dict(enumerate(df['crop'].cat.categories)))
# Out:
# Accuracy: 0.5049169209901662
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.58      0.67      0.62      2465
#            1       0.47      0.47      0.47      1604
#            2       0.40      0.31      0.35      1829
#
#     accuracy                           0.50      5898
#    macro avg       0.48      0.48      0.48      5898
# weighted avg       0.49      0.50      0.50      5898
#
#
# Confusion Matrix:
#  [[1646  374  445]
#  [ 432  757  415]
#  [ 769  485  575]]
#
# Label Mapping: {0: 'cocoa', 1: 'oil_palm', 2: 'rubber'}
